# %%
# %pip install --quiet phiflow
from phi.flow import *
from tqdm.notebook import trange

# %%
domain = Box(x=2, y=1)
sphere_x = math.sin(math.linspace(0, 1.5, batch(time=60))) * .5
sphere = Sphere(x=sphere_x, y=.5, radius=.3)
box = Box(x=(1, 3), y=(-1, .5))
mesh = geom.build_mesh(domain, x=30, y=10, obstacles=union(sphere, box))
plot(mesh, animate='time')
# Out:
# <video width="1200" height="500" controls autoplay loop>
#   <source type="video/mp4" src="...
